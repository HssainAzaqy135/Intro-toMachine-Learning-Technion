# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings

# Ignore all warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Preliminary: Updated Data Loading

# %% [markdown]
# * Task a

# %%
data = pd.read_csv("data_HW3.csv")
data.head()
# Out:
#    patient_id  age sex  weight blood_type          current_location  \
# 0         733   31   F    80.8         O-  ('11.93381', '79.82979')
# 1         382   29   F    63.0         O+   ('51.67822', '33.9162')
# 2        1164   44   F    74.2         O+  ('60.02427', '30.28491')
# 3         897    9   M    31.8         O-   ('51.08468', '7.11393')
# 4        1187   18   F    42.4         A-  ('38.45598', '48.87498')
#
#    num_of_siblings  happiness_score  household_income  conversations_per_day  \
# 0                6                6               0.7                      5
# 1                1                9               NaN                     11
# 2                2               10               1.5                      3
# 3                3                9               0.5                      8
# 4                0                8               0.2                      4
#
#    ...    PCR_02      PCR_03      PCR_04    PCR_05    PCR_06    PCR_07  \
# ...

# %% [markdown]
# * Task b + c

# %%
from prepare import prepare_data
from sklearn.model_selection import train_test_split
# Splitting to train and test sets
state = 4+76
train_df, test_df = train_test_split(data, test_size=0.2, random_state=state)
# Taking only pcr features
all_features = data.columns.tolist() 
pcr_features = [feature for feature in all_features if feature.startswith("PCR")] + ["contamination_level"]
# Prepare training set according to itself
train_df_prepared = prepare_data(train_df, train_df)[pcr_features]

# Prepare test set according to the raw training set
test_df_prepared = prepare_data(train_df, test_df)[pcr_features]


# Loading prepared data to csv files
train_df_prepared.to_csv("prepared_data/prepared_train_data.csv",index= False)
test_df_prepared.to_csv("prepared_data/prepared_test_data.csv",index= False)

# %% [markdown]
# * Checking

# %%
train_df = pd.read_csv("prepared_data/prepared_train_data.csv")
test_df = pd.read_csv("prepared_data/prepared_test_data.csv")
train_df.head()
# Out:
#      PCR_01    PCR_02    PCR_03    PCR_04    PCR_05    PCR_06    PCR_07  \
# 0 -0.319564 -0.938708  0.095833 -0.080588 -0.211693 -1.265944 -0.154870
# 1 -1.304385 -0.915717 -0.577759  1.010946 -0.865854 -0.042536 -0.734147
# 2  0.324314  2.297171  0.764570  0.762770 -0.695165  1.466016 -0.228026
# 3 -0.699246 -1.172286  0.051257  0.475773 -0.312904  0.226226  0.348053
# 4 -0.830385  0.124843 -0.145271  1.932064 -0.932569  1.546453  1.133531
#
#      PCR_08    PCR_09    PCR_10  contamination_level
# 0 -0.066155  2.040026 -0.211329             0.096351
# 1 -0.567384 -1.895055  0.532303             0.317113
# 2  0.744201  0.971091  0.814198            -0.120513
# 3 -0.941917  0.323985  0.285240             0.396919
# 4 -0.598434 -0.242652 -0.014333             0.397551

# %% [markdown]
# # Section 1: Linear regression implementation

# %% [markdown]
# * Data splitting for this section

# %%
s1_test_df = test_df
s1_train_df, s1_val_df = train_test_split(train_df, test_size=0.2, random_state=state)

# %%
s1_test_df.shape, s1_train_df.shape, s1_val_df.shape
# Out:
# ((250, 11), (800, 11), (200, 11))

# %% [markdown]
# * Implementation

# %%
from sklearn.base import BaseEstimator, RegressorMixin
import numpy as np

class LinearRegressor(BaseEstimator, RegressorMixin):
    """
    Custom linear regression model
    """
    def __init__(self, lr: float = 1e-5):
        """
        Initialize an instance of this class.
        ** Do not edit this method **

        :param lr: the SGD learning rate (step size)
        """
        self.lr = lr
        self.batch_size = 32
        self.w = None
        self.b = 0.0

    # Initialize a random weight vector
    def init_solution(self, n_features: int):
        """
        Randomize an initial solution (weight vector)
        ** Do not edit this method **

        :param n_features:
        """
        self.w = np.zeros(n_features)
        self.b = 0.0

    @staticmethod
    def loss(w, b: float, X, y):
        """
        Compute the MSE objective loss.

        :param w: weight vector for linear regression; array of shape (n_features,)
        :param b: bias scalar for linear regression
        :param X: samples for loss computation; array of shape (n_samples, n_features)
        :param y: targets for loss computation; array of shape (n_samples,)
        :return: the linear regression objective loss (float scalar)
        """

        # TODO: complete the loss calculation
        m = len(X)
        inner_term = np.dot(X,w)+ b - y
        loss = (1/m)*(np.linalg.norm(inner_term))**2

        return loss

    @staticmethod
    def gradient(w, b: float, X, y):
        """
        Compute the (analytical) linear regression objective gradient.

        :param w: weight vector for linear regression; array of shape (n_features,)
        :param b: bias scalar for linear regression
        :param X: samples for loss computation; array of shape (n_samples, n_features)
        :param y: targets for loss computation; array of shape (n_samples,)
        :return: a tuple with (the gradient of the weights, the gradient of the bias)
        """
        # TODO: calculate the analytical gradient w.r.t w and b
        # prep
        # converting X from DataFrame to NumPy array
        if isinstance(X, pd.DataFrame):
            X = X.to_numpy()
        
        # converting y from Series to NumPy array
        if isinstance(y, pd.Series):
            y = y.to_numpy()

        # w_grad calculation
        m = len(X)
        predictions = np.dot(X,w) +b
        inner_term_w = predictions - y
        g_w = (2/m)*(np.dot(X.T,inner_term_w))
        
        
        # b_grad calculation
        inner_term_b = inner_term_w - b
        g_b = 2*(b + (1/m)*np.sum(inner_term_b))

        return g_w, g_b

    def fit_with_logs(self, X, y, max_iter: int = 1000, keep_losses: bool = True,
                      X_val  =None, y_val = None):
        """
        Fit the model according to the given training data.

        :param X: training samples; array of shape (n_samples, n_features)
        :param y: training targets; array of shape (n_samples,)
        :param max_iter: number of SGD iterations
        :param keep_losses: should compute the train & val losses during training?
        :param X_val: validation samples to compute the loss for (for logs only)
        :param y_val: validation labels to compute the loss for (for logs only)
        :return: training and validation losses during training
        """
        # Initialize learned parameters
        self.init_solution(X.shape[1])

        train_losses = []
        val_losses = []

        if keep_losses:
            train_losses.append(self.loss(self.w, self.b, X, y))
            val_losses.append(self.loss(self.w, self.b, X_val, y_val))

        # Iterate over batches (SGD)
        for itr in range(0, max_iter):
            start_idx = (itr * self.batch_size) % X.shape[0]
            end_idx = min(X.shape[0], start_idx + self.batch_size)
            batch_X = X[start_idx: end_idx]
            batch_y = y[start_idx: end_idx]

            # TODO: Compute the gradient for the current *batch*
            g_w, g_b =  self.gradient(self.w, self.b, batch_X, batch_y)

            # Perform a gradient step
            # TODO: update the learned parameters correctly
            self.w = self.w - self.lr * g_w
            self.b = self.b - self.lr * g_b

            if keep_losses:
                train_losses.append(self.loss(self.w, self.b,  X, y))
                val_losses.append(self.loss(self.w, self.b,  X_val, y_val))

        return train_losses, val_losses

    def fit(self, X, y, max_iter: int = 1000):
        """
        Fit the model according to the given training data.
        ** Do not edit this method **

        :param X: training samples; array of shape (n_samples, n_features)
        :param y: training targets; array of shape (n_samples,)
        :param max_iter: number of SGD iterations
        """
        self.fit_with_logs(X, y, max_iter=max_iter, keep_losses=False)

        return self

    def predict(self, X):
        """
        Regress labels on samples in X.

        :param X: samples for prediction; array of shape (n_samples, n_features)
        :return: Predicted continuous labels for samples in X; array of shape (n_samples,)
        """

        # TODO: Compute
        y_pred = np.dot(X, self.w) + self.b

        return y_pred

# %% [markdown]
# * Question 2

# %%
import matplotlib.pyplot as plt

def numerical_subgradient(w, b, X, y, delta=1e-4):
    w_ = w.copy()
    g_w = np.zeros_like(w_)
    orig_objective = LinearRegressor.loss(w_, b, X, y)
    for i in range(g_w.shape[0]):
        w_[i] += delta
        perturbed_objective = LinearRegressor.loss(w_, b, X, y)
        w_[i] -= delta
        g_w[i] = (perturbed_objective - orig_objective) / delta

    g_b = (LinearRegressor.loss(w_, b + delta, X, y) - orig_objective) / delta
    return g_w, g_b


def compare_gradients(X, y, deltas, C=1, REPEATS=10, figsize=(10, 6)):
    residual_means_w = []
    residual_means_b = []

    for delta in deltas:
        residuals_w = []
        residuals_b = []

        for _ in range(REPEATS):
            # Randomize vectors in which the gradient is computed
            w = np.random.randn(X.shape[1])
            b = np.random.randn(1)

            # Compute the two types of gradients
            analytic_grad_w, analytic_grad_b = LinearRegressor.gradient(w, b, X, y)

            numeric_grad_w, numeric_grad_b = numerical_subgradient(w, b, X, y, delta=delta)

            residual_w = np.linalg.norm(numeric_grad_w - analytic_grad_w)
            residuals_w.append(residual_w)

            residual_b = np.linalg.norm(numeric_grad_b - analytic_grad_b)
            residuals_b.append(residual_b)

        residual_means_w.append(np.mean(residuals_w))
        residual_means_b.append(np.mean(residuals_b))

    fig, axs = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(16, 8))
    plt.suptitle('Residuals of analytical and numerical gradients',
                 fontsize=22, fontweight="bold")
    axs[0].set_title(r'Residuals of $\nabla_{w}L\left(w,b\right)$')
    axs[1].set_title(r'Residuals of $\frac{\partial}{\partial{b}}L\left(w,b\right)$')
    axs[0].plot(deltas, residual_means_w, linewidth=3)
    axs[1].plot(deltas, residual_means_b, linewidth=3)
    axs[0].set_yscale('log')
    axs[0].set_xscale('log')
    axs[1].set_yscale('log')
    axs[1].set_xscale('log')
    axs[0].set_xlabel('$\delta_w$', fontsize=18)
    axs[1].set_xlabel('$\delta_b$', fontsize=18)
    axs[0].set_ylabel(r'$\left\Vert \nabla_{w}L\left(w,b\right) - u_{\delta_w} \left(w,b\right)\right\Vert$',
                      fontsize=18)
    axs[1].set_ylabel(
        r'$\left\Vert \frac{\partial}{\partial{b}}L\left(w,b\right) - u_{\delta_b} \left(w,b\right)\right\Vert$',
        fontsize=18)

    axs[0].grid(alpha=0.5)
    axs[1].grid(alpha=0.5)
    plt.show()

# %%
X_train = s1_train_df.drop(["contamination_level"],axis=1)
y_train = s1_train_df["contamination_level"]

compare_gradients(X_train, y_train, deltas=np.logspace(-7, -2, 9))

# %% [markdown]
# * Question 3

# %%
def test_lr(X_train, y_train, X_val, y_val, title:str, max_iter = 1500):
  lr_list = np.logspace(-9, -1, 9)

  fig, axs = plt.subplots(3, 3, sharey=True, figsize=(20, 12))
  plt.suptitle(title, fontsize=32)
  plt.tight_layout()
  fig.subplots_adjust(hspace=0.5, top=0.9)
  
  axs = np.ravel(axs)
  for i, lr in enumerate(lr_list):
    cur_linear_reggressor = LinearRegressor(lr)
    train_losses, val_losses = cur_linear_reggressor.fit_with_logs(X_train, y_train, keep_losses=True, X_val=X_val, y_val=y_val, max_iter = max_iter)
    print('lr size = '+str(lr)+', Best train loss = '+str(min(train_losses))+', Best validation loss = '+str(min(val_losses)))

    iterations = np.arange(max_iter + 1)
    axs[i].semilogy(iterations, train_losses, label="Train")
    axs[i].semilogy(iterations, val_losses, label="Validation")
    axs[i].grid(alpha=0.5)
    axs[i].legend()
    axs[i].set_title('lr = '+str(lr))
    axs[i].set_xlabel('iteration')
    axs[i].set_ylabel('MSE')

# %%
X_train = s1_train_df.drop(["contamination_level"],axis=1)
y_train = s1_train_df["contamination_level"]

X_val = s1_val_df.drop(["contamination_level"],axis=1)
y_val = s1_val_df["contamination_level"]
test_lr(X_train = X_train, y_train = y_train, X_val= X_val, y_val= y_val,title="Convrgence per learning rate")
# Out:
# lr size = 1e-09, Best train loss = 0.07631351895494184, Best validation loss = 0.08555616713470707
# lr size = 1e-08, Best train loss = 0.07631064407314496, Best validation loss = 0.08555315558374867
# lr size = 1e-07, Best train loss = 0.07628190377997457, Best validation loss = 0.08552304891417745
# lr size = 1e-06, Best train loss = 0.0759953516165901, Best validation loss = 0.08522286446002557
# lr size = 1e-05, Best train loss = 0.07321322101883175, Best validation loss = 0.08230751059298688
# lr size = 0.0001, Best train loss = 0.05227381597739127, Best validation loss = 0.060302988271156405
# lr size = 0.001, Best train loss = 0.022724319344086995, Best validation loss = 0.02869937498193159
# lr size = 0.01, Best train loss = 0.022548071172539496, Best validation loss = 0.0283671790405016
# lr size = 0.1, Best train loss = 0.02268955267400382, Best validation loss = 0.027956543466381024

# %% [markdown]
# # Section 2: Evaluation and Baseline

# %% [markdown]
# * Data Preperation

# %%
train_df = pd.read_csv("prepared_data/prepared_train_data.csv")
test_df = pd.read_csv("prepared_data/prepared_test_data.csv")
s2_entire_train_df = train_df.copy()
s2_test_df = test_df.copy()
s2_train_df, s2_val_df = train_test_split(s2_entire_train_df, test_size=0.2, random_state=state)

# %% [markdown]
# * Question 4

# %%
from sklearn.model_selection import cross_validate
from sklearn.dummy import DummyRegressor

dum = DummyRegressor()
X_train = s2_train_df.drop(["contamination_level"],axis=1)
y_train = s2_train_df["contamination_level"]
cv_results = cross_validate(dum,
                            X = X_train,
                            y = y_train,
                            cv=5,
                            scoring='neg_mean_squared_error',
                           return_train_score=True)
mean_valid_score = cv_results["test_score"].mean()
mean_train_score = cv_results["train_score"].mean()
print(f"mean validation score is : { mean_valid_score}, mean train score is : { mean_train_score} ")
# Out:
# mean validation score is : -0.06655387736460414, mean train score is : -0.06624823283856855

# %% [markdown]
# * Dummy retraining on entire training set

# %%
dummy_regressor = DummyRegressor().fit(X = s2_entire_train_df.drop(["contamination_level"],axis=1),
                                      y = s2_entire_train_df["contamination_level"])

# %% [markdown]
# * Question 5

# %%
# def param grid
lrs = np.logspace(-7, -1, 7) 
# data prep
X_train = s2_train_df.drop(["contamination_level"],axis=1)
y_train = s2_train_df["contamination_level"]

# dict to store results
results = {'lrs': lrs, 'train_errors': [], 'valid_errors': []}

# CV for each learing rate
for lr in lrs:
    model = LinearRegressor(lr= lr)
    
    cv_results = cross_validate(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error', return_train_score=True)
    
    # Store results
    results['train_errors'].append(-cv_results['train_score'].mean())
    results['valid_errors'].append(-cv_results['test_score'].mean())


# Dummy regressor
dummy = DummyRegressor()
dummy_cv_results = cross_validate(dummy, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
dummy_valid_error = -dummy_cv_results['test_score'].mean()
# Plot train and validation errors
plt.semilogx(results['lrs'], results['train_errors'], label='Train Errors')
plt.semilogx(results['lrs'], results['valid_errors'], label='Validation Errors')
plt.axhline(y=dummy_valid_error, color='r', linestyle='--', label='Dummy Regressor Error')

# Add labels and legend
plt.xlabel('learning rate')
plt.ylabel('Mean Squared Error')
plt.title('Train and Validation Errors for different learning rates')
plt.legend()
plt.grid()
plt.show()

# %%
# Getting index of the min validation error
best_index = np.argmin(results['valid_errors'])
best_lr = results['lrs'][best_index]
best_error_val = results['valid_errors'][best_index]
best_error_train = results['train_errors'][best_index]

print(f"Optimal learning rate: {best_lr}")
print(f"Validation error at optimal learning rate: {best_error_val}")
print(f"Training error at optimal learning rate: {best_error_train}")
# Out:
# Optimal learning rate: 0.01
# Validation error at optimal learning rate: 0.023206892546040265
# Training error at optimal learning rate: 0.022476940802092688

# %% [markdown]
# * Training LinearRegressor on entire data with optimal Learning rate = 0.01

# %%
linear_regressor = LinearRegressor(lr = best_lr).fit(X = s2_entire_train_df.drop(["contamination_level"],axis=1),
                                      y = s2_entire_train_df["contamination_level"])

# %% [markdown]
# # Section 3: Lasso linear regression

# %%
from sklearn.linear_model import Lasso

# %% [markdown]
# * Question 7

# %%
# def param grid
alphas = np.logspace(-7, 2, 10) 
# data prep
X_train = s2_train_df.drop(["contamination_level"],axis=1)
y_train = s2_train_df["contamination_level"]

# dict to store results
results = {'alphas': alphas, 'train_errors': [], 'valid_errors': []}

# CV for each learing rate
for alpha in alphas:
    model = Lasso(alpha=alpha)
    
    cv_results = cross_validate(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error', return_train_score=True)
    
    # Store results
    results['train_errors'].append(-cv_results['train_score'].mean())
    results['valid_errors'].append(-cv_results['test_score'].mean())


# Dummy regressor
dummy = DummyRegressor()
dummy_cv_results = cross_validate(dummy, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
dummy_valid_error = -dummy_cv_results['test_score'].mean()
# Plot train and validation errors
plt.semilogx(results['alphas'], results['train_errors'], label='Train Errors')
plt.semilogx(results['alphas'], results['valid_errors'], label='Validation Errors')
plt.axhline(y=dummy_valid_error, color='r', linestyle='--', label='Dummy Regressor Error')

# Add labels and legend
plt.xlabel('regularization')
plt.ylabel('Mean Squared Error')
plt.title('Train and Validation Errors for different regularization terms')
plt.legend()
plt.grid()
plt.show()

# %%
# Getting index of the min validation error
best_index = np.argmin(results['valid_errors'])
best_alpha = results['alphas'][best_index]
best_error_val = results['valid_errors'][best_index]
best_error_train = results['train_errors'][best_index]

print(f"Optimal regularization alpha: {best_alpha}")
print(f"Validation error at optimal regularization alpha: {best_error_val}")
print(f"Training error at optimal regularization alpha: {best_error_train}")
# Out:
# Optimal regularization alpha: 0.001
# Validation error at optimal regularization alpha: 0.02313150258151016
# Training error at optimal regularization alpha: 0.022487430212685115

# %% [markdown]
# * Training Lasso with optimal regularization parameter = 0.001

# %%
lasso_regressor = Lasso(alpha=best_alpha).fit(X = s2_entire_train_df.drop(["contamination_level"],axis=1),
                                      y = s2_entire_train_df["contamination_level"])

# %% [markdown]
# * Question 9

# %%
feature_names = s2_train_df.columns
abs_coefficients = np.abs(lasso_regressor.coef_)
top_5_indecies = np.argsort(abs_coefficients)[-5:][::-1]
top_5_feature_names = feature_names[top_5_indecies]
top_5_feature_names
top_5_coefficients = abs_coefficients[top_5_indecies]
for feature, coef in zip(top_5_feature_names, top_5_coefficients):
    print(f"Feature: {feature}, Coefficient: {coef}")
# Out:
# Feature: PCR_04, Coefficient: 0.19188858316551433
# Feature: PCR_02, Coefficient: 0.07214066878226899
# Feature: PCR_06, Coefficient: 0.04064930398881351
# Feature: PCR_10, Coefficient: 0.009477510054158166
# Feature: PCR_09, Coefficient: 0.0054473287549780675

# %% [markdown]
# * Question 10

# %%
sorted_indices = np.argsort(abs_coefficients)[::-1]
sorted_coefs = abs_coefficients[sorted_indices]

# Plot the sorted absolute values of the coefficients
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(sorted_coefs)), sorted_coefs)
plt.xlabel('Index of Coef (Sorted decending)')
plt.ylabel('Abs Coef Value')
plt.title('Feature Coef Absolute Values by index sorted in decending order')
plt.grid(True)
plt.show()

# %% [markdown]
# # Section 4: Polynomial fitting (visualization)

# %%
train_df = pd.read_csv("prepared_data/prepared_train_data.csv")[["PCR_04","PCR_06","contamination_level"]]
test_df = pd.read_csv("prepared_data/prepared_test_data.csv")[["PCR_04","PCR_06","contamination_level"]]
s3_entire_train_df = train_df.copy()
s3_test_df = test_df.copy()
s3_train_df, s3_val_df = train_test_split(s3_entire_train_df, test_size=0.2, random_state=state)

# %% [markdown]
# * Plotting code

# %%
import seaborn as sns

def plot3d(df, colX:str, colY:str, colZ:str, title:str, predictions=None):
  fig = plt.figure(figsize=(20, 7))
  axes = [fig.add_subplot(1, 3, i+1, projection='3d') for i in range(3)]

  palette = sns.color_palette("hls", 2)

  for i,ax in enumerate(axes):
    if predictions is not None:
      ax.scatter3D(df[colX], df[colY], predictions, color=palette[1], s=3)
      ax.scatter3D(df[colX], df[colY], df[colZ], color=palette[0], s=1, 
                   alpha=0.35, depthshade=False)
    else:
      ax.scatter3D(df[colX], df[colY], df[colZ], color=palette[0], s=1)

    ax.set_xlabel(colX)
    ax.set_ylabel(colY)
    ax.xaxis.set_ticklabels([])
    ax.yaxis.set_ticklabels([])
    
    ax.view_init(elev=5., azim=45*i)
  
  axes[0].set_zlabel("\n" + colZ, linespacing=2.2)

  plt.suptitle(title, fontsize=32)
  plt.tight_layout()
  plt.show()

# %% [markdown]
# * Data visualization

# %%
plot3d(df= s3_entire_train_df,
       colX='PCR_04',
       colY='PCR_06',
       colZ='contamination_level',
       title="contamination_level spread relative to PCR_04 & PCR_06")

# %% [markdown]
# * Pipeline preperation

# %%
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler
from sklearn.pipeline import Pipeline
Lambda = 0.001
mapping_poly = PolynomialFeatures(degree=4)
lasso_reg = Pipeline([
('feature_mapping', mapping_poly),
('normalization', MinMaxScaler()),
('Lasso', Lasso(alpha=Lambda, fit_intercept=True))
])
X_train = s3_train_df.drop(["contamination_level"],axis = 1)
y_train = s3_train_df["contamination_level"]
lasso_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('feature_mapping', PolynomialFeatures(degree=4)),
#                 ('normalization', MinMaxScaler()),
#                 ('Lasso', Lasso(alpha=0.001))])

# %% [markdown]
# * Queston 15

# %% [markdown]
# * Regularization tuninig

# %%
# def param grid
alphas = np.logspace(-7, 2, 10) 
# data prep
X_train = s3_train_df.drop(["contamination_level"],axis=1)
y_train = s3_train_df["contamination_level"]
mapping_poly = PolynomialFeatures(degree=4)
scaler = MinMaxScaler()
# dict to store results
results = {'alphas': alphas, 'train_errors': [], 'valid_errors': []}

# CV for each learing rate
for alpha in alphas:
    model = Pipeline([
                    ('feature_mapping', mapping_poly),
                    ('normalization', scaler),
                    ('Lasso', Lasso(alpha=alpha, fit_intercept=True))
                    ])
    
    cv_results = cross_validate(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error', return_train_score=True)
    
    # Store results
    results['train_errors'].append(-cv_results['train_score'].mean())
    results['valid_errors'].append(-cv_results['test_score'].mean())


# Dummy regressor
dummy = DummyRegressor()
dummy_cv_results = cross_validate(dummy, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
dummy_valid_error = -dummy_cv_results['test_score'].mean()
# Plot train and validation errors
plt.semilogx(results['alphas'], results['train_errors'], label='Train Errors')
plt.semilogx(results['alphas'], results['valid_errors'], label='Validation Errors')
plt.axhline(y=dummy_valid_error, color='r', linestyle='--', label='Dummy Regressor Error')

# Add labels and legend
plt.xlabel('regularization')
plt.ylabel('Mean Squared Error')
plt.title('Train and Validation Errors for vs regularization terms')
plt.legend()
plt.grid()
plt.show()

# %%
# Getting index of the min validation error
best_index = np.argmin(results['valid_errors'])
best_alpha = results['alphas'][best_index]
best_error_val = results['valid_errors'][best_index]
best_error_train = results['train_errors'][best_index]

print(f"Optimal regularization alpha: {best_alpha}")
print(f"Validation error at optimal regularization alpha: {best_error_val}")
print(f"Training error at optimal regularization alpha: {best_error_train}")
# Out:
# Optimal regularization alpha: 0.001
# Validation error at optimal regularization alpha: 0.024509419331913352
# Training error at optimal regularization alpha: 0.02384382946755397

# %%
alpha = best_alpha
lasso_poly_reg = Pipeline([
                    ('feature_mapping', mapping_poly),
                    ('normalization', scaler),
                    ('Lasso', Lasso(alpha=alpha, fit_intercept=True))
                    ])
X_train = s3_entire_train_df.drop(["contamination_level"],axis = 1)
y_train = s3_entire_train_df["contamination_level"]
lasso_poly_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('feature_mapping', PolynomialFeatures(degree=4)),
#                 ('normalization', MinMaxScaler()),
#                 ('Lasso', Lasso(alpha=0.001))])

# %% [markdown]
# * Question 16

# %%
preds = lasso_poly_reg.predict(s3_entire_train_df.drop(["contamination_level"],axis = 1))

plot3d(df= s3_entire_train_df,
       predictions=preds,
       colX='PCR_04',
       colY='PCR_06',
       colZ='contamination_level',
       title="contamination_level spread relative to PCR_04 & PCR_06")

# %% [markdown]
# # Section 5: Fitting Gradient Boosted Machines (GBM) of the CovidScore

# %% [markdown]
# * Data preperation

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Splitting to train and test sets
state = 4+76
train_df, test_df = train_test_split(data, test_size=0.2, random_state=state)
# Taking only pcr features
all_features = data.columns.tolist() 
pcr_features_and_sugar = [feature for feature in all_features if feature.startswith("PCR")]  +["sugar_levels"] +["contamination_level"]
pcr_features_and_sugar = [feature for feature in pcr_features_and_sugar if feature not in ["PCR_07", "PCR_08"]]
# Prepare training set according to itself
train_df_prepared = prepare_data(train_df, train_df)[pcr_features_and_sugar]

# Prepare test set according to the raw training set
test_df_prepared = prepare_data(train_df, test_df)[pcr_features_and_sugar]

# scaling sugar levels
scaler = MinMaxScaler()

# Fit the scaler on the training set and transform the 'sugar_levels' column
train_df_prepared['sugar_levels'] = scaler.fit_transform(train_df_prepared[['sugar_levels']])

# Transform the 'sugar_levels' column in the test set using the same scaler
test_df_prepared['sugar_levels'] = scaler.transform(test_df_prepared[['sugar_levels']])

# Loading prepared data to csv files
train_df_prepared.to_csv("prepared_data/prepared_train_data_section5.csv",index= False)
test_df_prepared.to_csv("prepared_data/prepared_test_data_section5.csv",index= False)

# %%
s5_train_df = pd.read_csv("prepared_data/prepared_train_data_section5.csv")
s5_test_df = pd.read_csv("prepared_data/prepared_test_data_section5.csv")
s5_train_df.head()
# Out:
#      PCR_01    PCR_02    PCR_03    PCR_04    PCR_05    PCR_06    PCR_09  \
# 0 -0.319564 -0.938708  0.095833 -0.080588 -0.211693 -1.265944  2.040026
# 1 -1.304385 -0.915717 -0.577759  1.010946 -0.865854 -0.042536 -1.895055
# 2  0.324314  2.297171  0.764570  0.762770 -0.695165  1.466016  0.971091
# 3 -0.699246 -1.172286  0.051257  0.475773 -0.312904  0.226226  0.323985
# 4 -0.830385  0.124843 -0.145271  1.932064 -0.932569  1.546453 -0.242652
#
#      PCR_10  sugar_levels  contamination_level
# 0 -0.211329      0.431373             0.096351
# 1  0.532303      0.401961             0.317113
# 2  0.814198      0.441176            -0.120513
# 3  0.285240      0.647059             0.396919
# 4 -0.014333      0.460784             0.397551

# %% [markdown]
# * Question 18: tuning learning rate of Gradient boosted regressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

gb_reg = GradientBoostingRegressor(loss='huber', random_state=state)

# param grid
param_grid = {
    'learning_rate': np.logspace(-4, 0, 5) ,
    'min_samples_leaf': [1, 3, 5, 10]
}

grid_search = GridSearchCV(estimator=gb_reg,
                           param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error',
                           n_jobs=-1,
                           verbose=1)

grid_search.fit(s5_train_df.drop(["contamination_level"],axis = 1), s5_train_df["contamination_level"])

# Get the optimal parameters
opt_params = grid_search.best_params_
opt_train_error = -grid_search.best_score_
opt_model = grid_search.best_estimator_

# Validation Error on test set
test_predictions = opt_model.predict(s5_test_df.drop(["contamination_level"],axis = 1))
val_error = mean_squared_error(s5_test_df["contamination_level"], test_predictions)

# Generate a heatmap of the cross-validation results
results = pd.DataFrame(grid_search.cv_results_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits

# %% [markdown]
# * Heatmap

# %%
# Reshape results to get a matrix suitable for a heatmap
data = results.pivot(index='param_min_samples_leaf', columns='param_learning_rate', values='mean_test_score')

# Draw the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(-data, annot=True,cmap='viridis')
plt.title('Mean Validation Accuracy')
plt.xlabel('learning_rate')
plt.ylabel('min_samples_leaf')
plt.show()

# %%
# Print optimal hyperparameters and errors
print("Optimal Hyper params: ", opt_params)
print("Optimal Train Error: ", opt_train_error)
print("Validation Error: ", val_error)
# Out:
# Optimal Hyper params:  {'learning_rate': 0.1, 'min_samples_leaf': 3}
# Optimal Train Error:  0.0015133026206487735
# Validation Error:  0.0010523804993928887

# %%
gbm_reg = GradientBoostingRegressor(loss='huber',
                                    learning_rate=0.1,
                                    min_samples_leaf=5,
                                    random_state=state)

X_train = s5_train_df.drop(["contamination_level"],axis = 1)
y_train = s5_train_df["contamination_level"]
gbm_reg.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(loss='huber', min_samples_leaf=5, random_state=80)

# %% [markdown]
# # Section 6: Testing your models

# %%
model_list = {
    "Dummy": dummy_regressor,
    "Lin_reg": linear_regressor,
    "Lass_reg": lasso_regressor,
    "Poly_lass_reg": lasso_poly_reg,
    "GBM_reg": gbm_reg
}

test_predictions = [
    dummy_regressor.predict(s2_test_df.drop(["contamination_level"], axis=1)),
    linear_regressor.predict(s2_test_df.drop(["contamination_level"], axis=1)),
    lasso_regressor.predict(s2_test_df.drop(["contamination_level"], axis=1)),
    lasso_poly_reg.predict(s3_test_df.drop(["contamination_level"], axis=1)),
    gbm_reg.predict(s5_test_df.drop(["contamination_level"], axis=1))
]

test_results = [
    mean_squared_error(s2_test_df["contamination_level"], test_predictions[0]),
    mean_squared_error(s2_test_df["contamination_level"], test_predictions[1]),
    mean_squared_error(s2_test_df["contamination_level"], test_predictions[2]),
    mean_squared_error(s3_test_df["contamination_level"], test_predictions[3]),
    mean_squared_error(s5_test_df["contamination_level"], test_predictions[4])
]

model_names = list(model_list.keys())

bars = plt.bar(model_names, test_results, color='skyblue')

for bar, result in zip(bars, test_results):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f'{result:.5f}', ha='center', va='bottom')

plt.title('Hist of Test MSE for Different Models')
plt.xlabel('Model')
plt.ylabel('Mean Squared Error')
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.8)
plt.show()
